# %%
# Written by: Tanya Wen 2020/08/05
# use SPM to do analysis after fmriprep
# useful resources: https://miykael.github.io/nipype_tutorial/
# based on example from: https://github.com/niflows/nipype1-examples/blob/master/package/niflow/nipype1/examples/fmri_nipy_glm.py
# and: https://nipype.readthedocs.io/en/latest/users/examples/fmri_spm.html

from builtins import str
from builtins import range

from nipype.interfaces.nipy.model import FitGLM, EstimateContrast
from nipype.interfaces.nipy.preprocess import ComputeMask

import nipype.interfaces.io as nio  # Data i/o
import nipype.interfaces.spm as spm  # spm
import nipype.interfaces.matlab as mlab  # how to run matlab
import nipype.interfaces.utility as util  # utility
import nipype.pipeline.engine as pe  # pipeline engine
import nipype.algorithms.rapidart as ra  # artifact detection
import nipype.algorithms.modelgen as model  # model specification

from os.path import join as opj
import os  # system functionsimport nipype.interfaces.io as nio  # Data i/o
import shutil # move files

from nipype.interfaces.utility import IdentityInterface
from nipype.interfaces.io import SelectFiles, DataSink
from nipype.algorithms.rapidart import ArtifactDetect
from nipype import Workflow, Node

# %matplotlib inline
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np

from nipype.caching import Memory #idk why this is here, but it keeps things from crashing due to memory
mem = Memory(base_dir='.')
# Out:
# 220714-19:02:06,193 nipype.utils WARNING:
# 	 A newer version (1.8.3) of nipy/nipype is available. You are using 1.5.0

# %%
# Set the way matlab should be called
mlab.MatlabCommand.set_default_matlab_cmd("matlab -nodesktop -nosplash")

# %%
# Specify the location of the data.
datadir = '/media/tw260/X6/Effort/fMRI_BIDS/derivatives/fmriprep'
outputdir = '/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1'
# Specify the subject directories
subject_list = ['s01','s02','s03','s04','s05','s06','s08','s09','s10','s11','s12','s13','s14','s15','s16','s18','s19','s20','s23','s24','s25','s26','s27','s29','s31']
subject_num = [x.replace('s','') for x in subject_list]

# %%
# Convert .nii..gz to .nii for SPM and drop dummy scans

from nipype.algorithms.misc import Gunzip
from nipype import MapNode

for i in range(len(subject_list)):
    # current subject
    cur_sub = subject_list[i]
    # Functional scans
    #I have 5 runs per person, so this iterates through each run
    for j in range(0,5):
        # find the source epi
        cur_task = "effort"
        if not os.path.isfile(os.path.join(outputdir, cur_sub, "func", "sub-%s_run-%d.nii"%(cur_sub, j+1))):

            # gunzip
            nii_gz = "sub-%s_task-%s_run-%d_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz"%(cur_sub, cur_task, j+1)
            print(nii_gz)
            gunzip_in_file = os.path.join(datadir, "sub-%s"%cur_sub, "func", nii_gz)

            gunzip = MapNode(Gunzip(), name='gunzip', iterfield=['in_file'])
            gunzip.inputs.in_file = gunzip_in_file
            gunzip_res = gunzip.run()

            gunzip_out_file = "sub-%s_task-%s_run-%d_space-MNI152NLin2009cAsym_desc-preproc_bold.nii"%(cur_sub, cur_task, j+1)
            shutil.move(gunzip_res.outputs.out_file[0], os.path.join(datadir, "sub-%s"%cur_sub, "func", gunzip_out_file))

            # remove dummy scans
            from nipype.interfaces.fsl import ExtractROI
            #We decided to ask the scanner to keep the 5 dummies, so we need to manually discard them
            extract = MapNode(ExtractROI(t_min=5, t_size=-1, output_type='NIFTI'),name="extract", iterfield=['in_file'])  

            extract.inputs.in_file = os.path.join(datadir, "sub-%s"%cur_sub, "func", gunzip_out_file)
            extract_res = extract.run()
            res_out_file = "sub-%s_run-%d.nii"%(cur_sub, j+1)
            os.makedirs(os.path.join(outputdir, cur_sub, "func"), exist_ok=True)
            shutil.move(extract_res.outputs.roi_file[0], os.path.join(outputdir, cur_sub, "func", res_out_file))

# %%
# Here we set up iteration over all the subjects.
infosource = pe.Node(
    interface=util.IdentityInterface(fields=['subject_id']), name="infosource")# Specify the location of the data.

infosource.iterables = ('subject_id', subject_list)

# %%
# get data (mmore info on DataGrabbler can be found here: https://nipype.readthedocs.io/en/0.11.0/users/grabbing_and_sinking.html)
datasource = pe.Node(
    interface=nio.DataGrabber(
        infields=['subject_id'], outfields=['func']),
    name='datasource')
datasource.inputs.base_directory = outputdir
datasource.inputs.template = '*'
datasource.inputs.field_template = dict(func='%s/func/sub-%s_run-%s.nii')
datasource.inputs.template_args =  dict(func=[['subject_id', 'subject_id', ['1','2','3','4','5']]])
datasource.inputs.sort_filelist = True

# %%
# Smooth the functional data using nipype.interfaces.spm.Smooth.
# Use two different smoothing kernels
smooth = pe.Node(interface=spm.Smooth(), name="smooth")
fwhmlist = [0,10]
smooth.iterables = ('fwhm', fwhmlist)

# %%
#Here we create a function that returns subject-specific information about the experimental paradigm. This is used by the nipype.interfaces.spm.SpecifyModel to create the information necessary to generate an SPM design matrix. 
def subjectinfo(subject_id):
    from nipype.interfaces.base import Bunch
    from copy import deepcopy
    import os  # system functionsimport nipype.interfaces.io as nio  # Data i/o
    import pandas as pd
    #this allows FSL to access the data according to BIDS format
    bids_dir = '/media/tw260/X6/Effort/fMRI_BIDS/'
    model_dir = '/media/tw260/X6/Effort/behav'
    print("Subject ID: %s\n" % str(subject_id))

    task_id = "effort"

    output = []
    for r in range(5):
        #this pulls up the confound file from fmriprep
        confounds = pd.read_csv(os.path.join(bids_dir, "derivatives", "fmriprep", 
        "sub-%s"%subject_id.replace('_',''), "func", 
        "sub-%s_task-%s_run-%s_desc-confounds_timeseries.tsv"%(subject_id.replace('_',''), task_id, r+1)),
        sep="\t", na_values="n/a", skiprows=range(1,6))


        #get the behavioral data to make the glm
        events = pd.read_csv(os.path.join(model_dir, subject_id, "Effort_run-%02d_events_Model1.csv"%(r+1)))

        output.insert(r,
                    Bunch(
                    #first we have our condition, events, their durations, etc
                    conditions=['cue-easy',
                                'cue-hard',
                                'level1',
                                'level2',
                                'level3',
                                'level4',
                                'level5',
                                'level6',
                                'error'],
                    onsets=[list(events[events.trial_type == 'cue-easy'].onset),
                            list(events[events.trial_type == 'cue-hard'].onset),
                            list(events[events.trial_type == 'level1'].onset),
                            list(events[events.trial_type == 'level2'].onset),
                            list(events[events.trial_type == 'level3'].onset),
                            list(events[events.trial_type == 'level4'].onset),
                            list(events[events.trial_type == 'level5'].onset),
                            list(events[events.trial_type == 'level6'].onset),
                            list(events[events.trial_type == 'error'].onset)],
                    durations=[list(events[events.trial_type == 'cue-easy'].duration),
                            list(events[events.trial_type == 'cue-hard'].duration),
                            list(events[events.trial_type == 'level1'].duration),
                            list(events[events.trial_type == 'level2'].duration),
                            list(events[events.trial_type == 'level3'].duration),
                            list(events[events.trial_type == 'level4'].duration),
                            list(events[events.trial_type == 'level5'].duration),
                            list(events[events.trial_type == 'level6'].duration),
                            list(events[events.trial_type == 'error'].duration)],
                    #we can add in regressors we care to mode. Here I add in some confounds from the file
                    #note, I start the iteration at '5' because of how many initial slices we throw away (2 sec TR)
                    regressors=[list(confounds.trans_x),
                                list(confounds.trans_y),
                                list(confounds.trans_z),
                                list(confounds.rot_x),
                                list(confounds.rot_y),
                                list(confounds.rot_z)
                                ],
                    regressor_names=['trans_x',
                                    'trans_y',
                                    'trans_z',
                                    'rot_x',
                                    'rot_y',
                                    'rot_z'],
                    amplitudes=None,
                    tmod=None,
                    pmod=None))

    return output

# %%
# Setup the contrast structure that needs to be evaluated. This is a list of lists. The inner list specifies the contrasts and has the following format - [Name,Stat,[list of condition names],[weights on those conditions]. The condition names must match the names listed in the subjectinfo function described above.

#specify the contrasts you care about
all_cond_names = ['cue-easy','cue-hard','level1','level2','level3','level4','level5','level6']

cue_easy = (f'{all_cond_names[0]}','T',all_cond_names, [1, 0, 0, 0, 0, 0, 0, 0]) #1
cue_hard = (f'{all_cond_names[1]}','T',all_cond_names, [0, 1, 0, 0, 0, 0, 0, 0]) #2
level1 = (f'{all_cond_names[2]}','T',all_cond_names, [0, 0, 1, 0, 0, 0, 0, 0])   #3
level2 = (f'{all_cond_names[3]}','T',all_cond_names, [0, 0, 0, 1, 0, 0, 0, 0])   #4
level3 = (f'{all_cond_names[4]}','T',all_cond_names, [0, 0, 0, 0, 1, 0, 0, 0])   #5
level4 = (f'{all_cond_names[5]}','T',all_cond_names, [0, 0, 0, 0, 0, 1, 0, 0])   #6
level5 = (f'{all_cond_names[6]}','T',all_cond_names, [0, 0, 0, 0, 0, 0, 1, 0])   #7
level6 = (f'{all_cond_names[7]}','T',all_cond_names, [0, 0, 0, 0, 0, 0, 0, 1])   #8


cue_hard_vs_easy = ('cue_hard_vs_easy','T',all_cond_names,[-1, 1, 0, 0, 0, 0, 0, 0])  #9
cue_easy_vs_hard = ('cue_easy_vs_hard','T',all_cond_names,[1, -1, 0, 0, 0, 0, 0, 0])  #10
between_context_hard_vs_easy = ('between_context_hard_vs_easy','T',all_cond_names,[0, 0, -1/3, -1/3, -1/3, 1/3, 1/3, 1/3])  #11
between_context_easy_vs_hard = ('between_context_easy_vs_hard','T',all_cond_names,[0, 0, 1/3, 1/3, 1/3, -1/3, -1/3, -1/3])  #12
hard_context_hard_vs_easy = ('hard_context_hard_vs_easy','T',all_cond_names,[0, 0, 0, 0, 0, -1, 0, 1])  #13
hard_context_easy_vs_hard = ('hard_context_easy_vs_hard','T',all_cond_names,[0, 0, 0, 0, 0, 1, 0, -1])  #14
easy_context_hard_vs_easy = ('easy_context_hard_vs_easy','T',all_cond_names,[0, 0, -1, 0, 1, 0, 0, 0])  #15
easy_context_easy_vs_hard = ('easy_context_easy_vs_hard','T',all_cond_names,[0, 0, 1, 0, -1, 0, 0, 0])  #16
level_4_vs_1 = ('level_4_vs_1','T',all_cond_names,[0, 0, -1, 0, 0, 1, 0, 0])  #17
level_1_vs_4 = ('level_1_vs_4','T',all_cond_names,[0, 0, 1, 0, 0, -1, 0, 0])  #18
level_5_vs_2 = ('level_5_vs_2','T',all_cond_names,[0, 0, 0, -1, 0, 0, 1, 0])  #19
level_2_vs_5 = ('level_2_vs_5','T',all_cond_names,[0, 0, 0, 1, 0, 0, -1, 0])  #20
level_6_vs_3 = ('level_6_vs_3','T',all_cond_names,[0, 0, 0, 0, -1, 0, 0, 1])  #21
level_3_vs_6 = ('level_3_vs_6','T',all_cond_names,[0, 0, 0, 0, 1, 0, 0, -1])  #22
level_4_vs_3 = ('level_4_vs_3','T',all_cond_names,[0, 0, 0, 0, -1, 1, 0, 0])  #23
level_3_vs_4 = ('level_3_vs_4','T',all_cond_names,[0, 0, 0, 0, 1, -1, 0, 0])  #24

contrasts = [cue_easy, cue_hard, level1, level2, level3, level4, level5, level6, cue_hard_vs_easy, cue_easy_vs_hard, 
between_context_hard_vs_easy, between_context_easy_vs_hard, hard_context_hard_vs_easy, hard_context_easy_vs_hard, 
easy_context_hard_vs_easy, easy_context_easy_vs_hard, level_4_vs_1, level_1_vs_4, level_5_vs_2, level_2_vs_5, 
level_6_vs_3, level_3_vs_6, level_4_vs_3, level_3_vs_4]

# %%
# Generate design information using nipype.interfaces.spm.SpecifyModel. nipy accepts only design specified in seconds so “output_units” has always have to be set to “secs”.
modelspec = pe.Node(interface=model.SpecifySPMModel(), name="modelspec")
modelspec.inputs.concatenate_runs = False
modelspec.inputs.input_units = 'secs'
modelspec.inputs.output_units = 'secs'
modelspec.inputs.time_repetition = 2
modelspec.inputs.high_pass_filter_cutoff = 128

# %%
# Generate a first level SPM.mat file for analysis nipype.interfaces.spm.Level1Design.
level1design = pe.Node(interface=spm.Level1Design(), name="level1design")
level1design.inputs.timing_units = modelspec.inputs.output_units
level1design.inputs.interscan_interval = modelspec.inputs.time_repetition
level1design.inputs.bases = {'hrf': {'derivs': [0, 0]}}

# %%
# Use nipype.interfaces.spm.EstimateModel to determine the parameters of the model.
level1estimate = pe.Node(interface=spm.EstimateModel(), name="level1estimate")
level1estimate.inputs.estimation_method = {'Classical': 1}

# %%
# Use nipype.interfaces.spm.EstimateContrast to estimate the first level contrasts specified in a few steps above.
contrastestimate = pe.Node(
    interface=spm.EstimateContrast(), name="contrastestimate")
contrastestimate.inputs.contrasts = contrasts
contrastestimate.overwrite = True
contrastestimate.config = {'execution': {'remove_unnecessary_outputs': False}}

# %%
# Setup the pipeline
# The nodes created above do not describe the flow of data. They merely describe the parameters used for each function. In this section we setup the connections between the nodes such that appropriate outputs from nodes are piped into appropriate inputs of other nodes.

l1pipeline = pe.Workflow(name="level1")
l1pipeline.base_dir = os.path.abspath("/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1")

l1pipeline.connect(
    [(infosource, datasource, [('subject_id', 'subject_id')]),
     (datasource, smooth, [('func', 'in_files')]),
     (smooth, modelspec,[('smoothed_files', 'functional_runs')]), 
     (infosource, modelspec, [(("subject_id", subjectinfo), "subject_info")]), 
     (modelspec, level1design, [('session_info', 'session_info')]),
     (level1design, level1estimate, [('spm_mat_file', 'spm_mat_file')]),
     (level1estimate, contrastestimate,[('spm_mat_file', 'spm_mat_file'), ('beta_images', 'beta_images'),('residual_image', 'residual_image')])])

# %%
# Create pipeline output graph
l1pipeline.write_graph(graph2use='colored', format='png', simple_form=True)

# Visualize the graph
from IPython.display import Image
Image(filename=opj(l1pipeline.base_dir, 'level1', 'graph.png'))
# Out:
# 220714-19:02:11,473 nipype.workflow INFO:
# 	 Generated workflow graph: /media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/graph.png (graph2use=colored, simple_form=True).

# %%
# Setup storage results
# Use nipype.interfaces.io.DataSink to store selected outputs from the pipeline in a specific location. This allows the user to selectively choose important output bits from the analysis and keep them.
# The first step is to create a datasink node and then to connect outputs from the modules above to storage locations. These take the following form directory_name[.[@]subdir] where parts between [] are optional. For example ‘realign.@mean’ below creates a directory called realign in ‘l1output/subject_id/’ and stores the mean image output from the Realign process in the realign directory. If the @ is left out, then a sub-directory with the name ‘mean’ would be created and the mean image would be copied to that directory.

datasink = pe.Node(interface=nio.DataSink(), name="datasink")
datasink.inputs.base_directory = os.path.abspath('/media/tw260/X6/Effort/analysis/l1output-Effort-Model1')


def getstripdir(subject_id):
    import os
    return os.path.join(
        os.path.abspath('/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1'),
        '_subject_id_%s' % subject_id)


# store relevant outputs from various stages of the 1st level analysis
l1pipeline.connect([
    (infosource, datasink, [('subject_id', 'container'),
                            (('subject_id', getstripdir), 'strip_dir')]),
    (level1design, datasink, [('spm_mat_file', 'model.pre-estimate')]),
    (level1estimate, datasink, [('spm_mat_file', 'model.@spm'), ('beta_images', 'model.@beta'),
                            ('mask_image', 'model.@mask'), ('residual_image', 'model.@res'),
                            ('RPVimage', 'model.@rpv')]),
    (contrastestimate, datasink, [('spm_mat_file', 'contrasts.@spm'),
                                  ('con_images', 'contrasts.@con'),
                                  ('spmT_images', 'contrasts.@T')]),
])

# %%
# Use nipype.interfaces.io.DataGrabber to extract the contrast ges across a group of first level subjects. Unlike the previous pipeline that iterated over subjects, this pipeline will iterate over

# collect all the con images for each contrast.
contrast_ids = list(range(1, len(contrasts) + 1))
l2source = pe.Node(nio.DataGrabber(infields=['fwhm', 'con']), name="l2source")
# we use .*i* to capture both .img (SPM8) and .nii (SPM12)
l2source.inputs.template = os.path.abspath(
    '/media/tw260/X6/Effort/analysis/l1output-Effort-Model1/*/con*/*/_fwhm_%d/con_%04d.*i*')
# iterate over all contrast images
l2source.iterables = [('fwhm', fwhmlist), ('con', contrast_ids)]
l2source.inputs.sort_filelist = True

# %%
# Use nipype.interfaces.spm.OneSampleTTestDesign to perform a simple statistical analysis of the contrasts from the group of n this example).
# setup a 1-sample t-test node
onesamplettestdes = pe.Node(
    interface=spm.OneSampleTTestDesign(), name="onesampttestdes")
l2estimate = pe.Node(interface=spm.EstimateModel(), name="level2estimate")
l2estimate.inputs.estimation_method = {'Classical': 1}
l2conestimate = pe.Node(
    interface=spm.EstimateContrast(), name="level2conestimate")
cont1 = ('Group', 'T', ['mean'], [1])
l2conestimate.inputs.contrasts = [cont1]
l2conestimate.inputs.group_contrast = True

# %%
# As before, we setup a pipeline to connect these two nodes (l2source lettest).
l2pipeline = pe.Workflow(name="level2")
l2pipeline.base_dir = os.path.abspath('/media/tw260/X6/Effort/analysis/l2output-Effort-Model1')
l2pipeline.connect([
    (l2source, onesamplettestdes, [('outfiles', 'in_files')]),
    (onesamplettestdes, l2estimate, [('spm_mat_file', 'spm_mat_file')]),
    (l2estimate, l2conestimate, [('spm_mat_file', 'spm_mat_file'), ('beta_images', 'beta_images'),
                                ('residual_image', 'residual_image')]),
])

# %%
# Execute the pipeline
if __name__ == '__main__':
    l1pipeline.run('MultiProc')
    l2pipeline.run('MultiProc')
# Out:
# 220714-19:02:11,781 nipype.workflow INFO:
# 	 Workflow level1 settings: ['check', 'execution', 'logging', 'monitoring']
# Subject ID: s31
#
# Subject ID: s31
#
# Subject ID: s29
#
# Subject ID: s29
#
# Subject ID: s27
#
# Subject ID: s27
#
# Subject ID: s26
#
# Subject ID: s26
#
# Subject ID: s25
#
# Subject ID: s25
#
# Subject ID: s24
#
# Subject ID: s24
#
# Subject ID: s23
#
# Subject ID: s23
#
# Subject ID: s20
#
# Subject ID: s20
#
# Subject ID: s19
#
# Subject ID: s19
#
# Subject ID: s18
#
# Subject ID: s18
#
# Subject ID: s16
#
# Subject ID: s16
#
# Subject ID: s15
#
# Subject ID: s15
#
# Subject ID: s14
#
# Subject ID: s14
#
# Subject ID: s13
#
# Subject ID: s13
#
# Subject ID: s12
#
# Subject ID: s12
#
# Subject ID: s11
#
# Subject ID: s11
#
# Subject ID: s10
#
# Subject ID: s10
#
# Subject ID: s09
#
# Subject ID: s09
#
# Subject ID: s08
#
# Subject ID: s08
#
# Subject ID: s06
#
# Subject ID: s06
#
# Subject ID: s05
#
# Subject ID: s05
#
# Subject ID: s04
#
# Subject ID: s04
#
# Subject ID: s03
#
# Subject ID: s03
#
# Subject ID: s02
#
# Subject ID: s02
#
# Subject ID: s01
#
# Subject ID: s01
#
# 220714-19:02:46,686 nipype.workflow INFO:
# 	 Running in parallel.
# 220714-19:02:46,720 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 25 jobs ready. Free memory (GB): 28.03/28.03, Free processors: 12/12.
# 220714-19:02:46,990 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.datasource" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s31/datasource".
# 220714-19:02:47,148 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.datasource" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s29/datasource".
# 220714-19:02:47,361 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.datasource" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s27/datasource".
# 220714-19:02:47,514 nipype.workflow INFO:
# 	 [Node] Running "datasource" ("nipype.interfaces.io.DataGrabber")
# 220714-19:02:47,590 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.datasource" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s26/datasource".
# 220714-19:02:47,738 nipype.workflow INFO:
# 	 [Node] Running "datasource" ("nipype.interfaces.io.DataGrabber")
# 220714-19:02:47,805 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.datasource" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s25/datasource".
# 220714-19:02:47,959 nipype.workflow INFO:
# 	 [Node] Running "datasource" ("nipype.interfaces.io.DataGrabber")
# 220714-19:02:48,3 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.datasource" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s24/datasource".
# 220714-19:02:48,107 nipype.workflow INFO:
# 	 [Node] Finished "level1.datasource".
# 220714-19:02:48,224 nipype.workflow INFO:
# 	 [Node] Running "datasource" ("nipype.interfaces.io.DataGrabber")
# 220714-19:02:48,248 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.datasource" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s23/datasource".
# 220714-19:02:48,378 nipype.workflow INFO:
# 	 [Node] Finished "level1.datasource".
# 220714-19:02:48,472 nipype.workflow INFO:
# 	 [Node] Running "datasource" ("nipype.interfaces.io.DataGrabber")
# 220714-19:02:48,506 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.datasource" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s20/datasource".
# 220714-19:02:48,597 nipype.workflow INFO:
# 	 [Node] Finished "level1.datasource".
# 220714-19:02:48,636 nipype.workflow INFO:
# 	 [Node] Running "datasource" ("nipype.interfaces.io.DataGrabber")
# 220714-19:02:48,690 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.datasource" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s19/datasource".
# 220714-19:02:48,826 nipype.workflow INFO:
# 	 [Node] Running "datasource" ("nipype.interfaces.io.DataGrabber")
# 220714-19:02:48,838 nipype.workflow INFO:
# 	 [Node] Finished "level1.datasource".
# 220714-19:02:48,870 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.datasource" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s18/datasource".
# 220714-19:02:49,26 nipype.workflow INFO:
# 	 [Node] Finished "level1.datasource".
# 220714-19:02:49,97 nipype.workflow INFO:
# 	 [Node] Running "datasource" ("nipype.interfaces.io.DataGrabber")
# 220714-19:02:49,107 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.datasource" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s16/datasource".
# 220714-19:02:49,196 nipype.workflow INFO:
# 	 [Node] Finished "level1.datasource".
# 220714-19:02:49,239 nipype.workflow INFO:
# 	 [Node] Running "datasource" ("nipype.interfaces.io.DataGrabber")
# 220714-19:02:49,310 nipype.workflow INFO:
# 	 [Job 0] Completed (level1.datasource).
# 220714-19:02:49,312 nipype.workflow INFO:
# 	 [Job 13] Completed (level1.datasource).
# 220714-19:02:49,312 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.datasource" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s15/datasource".
# 220714-19:02:49,314 nipype.workflow INFO:
# 	 [Job 26] Completed (level1.datasource).
# 220714-19:02:49,316 nipype.workflow INFO:
# 	 [Job 39] Completed (level1.datasource).
# 220714-19:02:49,318 nipype.workflow INFO:
# 	 [Job 52] Completed (level1.datasource).
# 220714-19:02:49,320 nipype.workflow INFO:
# 	 [Job 65] Completed (level1.datasource).
# 220714-19:02:49,322 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 25 jobs ready. Free memory (GB): 26.83/28.03, Free processors: 6/12.
#                      Currently running:
#                        * level1.datasource
#                        * level1.datasource
#                        * level1.datasource
#                        * level1.datasource
#                        * level1.datasource
#                        * level1.datasource
# 220714-19:02:49,404 nipype.workflow INFO:
# 	 [Node] Finished "level1.datasource".
# 220714-19:02:49,423 nipype.workflow INFO:
# 	 [Node] Running "datasource" ("nipype.interfaces.io.DataGrabber")
# 220714-19:02:49,526 nipype.workflow INFO:
# 	 [Job 1] Cached (level1.smooth).
# 220714-19:02:49,614 nipype.workflow INFO:
# 	 [Node] Finished "level1.datasource".
# 220714-19:02:49,629 nipype.workflow INFO:
# 	 [Node] Running "datasource" ("nipype.interfaces.io.DataGrabber")
# 220714-19:02:49,652 nipype.workflow INFO:
# 	 [Job 7] Cached (level1.smooth).
# 220714-19:02:49,817 nipype.workflow INFO:
# 	 [Node] Finished "level1.datasource".
# 220714-19:02:49,831 nipype.workflow INFO:
# 	 [Job 14] Cached (level1.smooth).
# 220714-19:02:49,854 nipype.workflow INFO:
# 	 [Node] Running "datasource" ("nipype.interfaces.io.DataGrabber")
# 220714-19:02:49,934 nipype.workflow INFO:
# 	 [Job 20] Cached (level1.smooth).
# 220714-19:02:49,962 nipype.workflow INFO:
# 	 [Node] Finished "level1.datasource".
# 220714-19:02:50,58 nipype.workflow INFO:
# 	 [Job 27] Cached (level1.smooth).
# 220714-19:02:50,114 nipype.workflow INFO:
# 	 [Node] Finished "level1.datasource".
# 220714-19:02:50,149 nipype.workflow INFO:
# 	 [Job 33] Cached (level1.smooth).
# 220714-19:02:50,276 nipype.workflow INFO:
# 	 [Node] Finished "level1.datasource".
# 220714-19:02:51,313 nipype.workflow INFO:
# 	 [Job 78] Completed (level1.datasource).
# 220714-19:02:51,317 nipype.workflow INFO:
# 	 [Job 91] Completed (level1.datasource).
# 220714-19:02:51,321 nipype.workflow INFO:
# 	 [Job 104] Completed (level1.datasource).
# 220714-19:02:51,326 nipype.workflow INFO:
# 	 [Job 117] Completed (level1.datasource).
# 220714-19:02:51,330 nipype.workflow INFO:
# 	 [Job 130] Completed (level1.datasource).
# 220714-19:02:51,335 nipype.workflow INFO:
# 	 [Job 143] Completed (level1.datasource).
# 220714-19:02:51,344 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 37 jobs ready. Free memory (GB): 28.03/28.03, Free processors: 12/12.
# 220714-19:02:51,596 nipype.workflow INFO:
# 	 [Job 2] Cached (level1.modelspec).
# 220714-19:02:51,764 nipype.workflow INFO:
# 	 [Job 8] Cached (level1.modelspec).
# 220714-19:02:51,968 nipype.workflow INFO:
# 	 [Job 15] Cached (level1.modelspec).
# 220714-19:02:52,122 nipype.workflow INFO:
# 	 [Job 21] Cached (level1.modelspec).
# 220714-19:02:52,300 nipype.workflow INFO:
# 	 [Job 28] Cached (level1.modelspec).
# 220714-19:02:52,683 nipype.workflow INFO:
# 	 [Job 34] Cached (level1.modelspec).
# 220714-19:02:52,817 nipype.workflow INFO:
# 	 [Job 40] Cached (level1.smooth).
# 220714-19:02:52,911 nipype.workflow INFO:
# 	 [Job 46] Cached (level1.smooth).
# 220714-19:02:53,53 nipype.workflow INFO:
# 	 [Job 53] Cached (level1.smooth).
# 220714-19:02:53,126 nipype.workflow INFO:
# 	 [Job 59] Cached (level1.smooth).
# 220714-19:02:53,272 nipype.workflow INFO:
# 	 [Job 66] Cached (level1.smooth).
# 220714-19:02:53,352 nipype.workflow INFO:
# 	 [Job 72] Cached (level1.smooth).
# 220714-19:02:58,448 nipype.workflow INFO:
# 	 [Job 3] Cached (level1.level1design).
# 220714-19:02:59,629 nipype.workflow INFO:
# 	 [Job 9] Cached (level1.level1design).
# 220714-19:03:00,851 nipype.workflow INFO:
# 	 [Job 16] Cached (level1.level1design).
# 220714-19:03:02,43 nipype.workflow INFO:
# 	 [Job 22] Cached (level1.level1design).
# 220714-19:03:03,282 nipype.workflow INFO:
# 	 [Job 29] Cached (level1.level1design).
# 220714-19:03:05,491 nipype.workflow INFO:
# 	 [Job 35] Cached (level1.level1design).
# 220714-19:03:05,674 nipype.workflow INFO:
# 	 [Job 41] Cached (level1.modelspec).
# 220714-19:03:05,849 nipype.workflow INFO:
# 	 [Job 47] Cached (level1.modelspec).
# 220714-19:03:06,5 nipype.workflow INFO:
# 	 [Job 54] Cached (level1.modelspec).
# 220714-19:03:06,172 nipype.workflow INFO:
# 	 [Job 60] Cached (level1.modelspec).
# 220714-19:03:06,349 nipype.workflow INFO:
# 	 [Job 67] Cached (level1.modelspec).
# 220714-19:03:06,521 nipype.workflow INFO:
# 	 [Job 73] Cached (level1.modelspec).
# 220714-19:03:06,683 nipype.workflow INFO:
# 	 [Job 4] Cached (level1.level1estimate).
# 220714-19:03:06,792 nipype.workflow INFO:
# 	 [Job 10] Cached (level1.level1estimate).
# 220714-19:03:06,908 nipype.workflow INFO:
# 	 [Job 17] Cached (level1.level1estimate).
# 220714-19:03:07,6 nipype.workflow INFO:
# 	 [Job 23] Cached (level1.level1estimate).
# 220714-19:03:07,98 nipype.workflow INFO:
# 	 [Job 30] Cached (level1.level1estimate).
# 220714-19:03:07,197 nipype.workflow INFO:
# 	 [Job 36] Cached (level1.level1estimate).
# 220714-19:03:08,355 nipype.workflow INFO:
# 	 [Job 42] Cached (level1.level1design).
# 220714-19:03:09,577 nipype.workflow INFO:
# 	 [Job 48] Cached (level1.level1design).
# 220714-19:03:10,724 nipype.workflow INFO:
# 	 [Job 55] Cached (level1.level1design).
# 220714-19:03:11,930 nipype.workflow INFO:
# 	 [Job 61] Cached (level1.level1design).
# 220714-19:03:13,214 nipype.workflow INFO:
# 	 [Job 68] Cached (level1.level1design).
# 220714-19:03:14,422 nipype.workflow INFO:
# 	 [Job 74] Cached (level1.level1design).
# 220714-19:03:18,193 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.contrastestimate" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s31/_fwhm_10/contrastestimate".
# 220714-19:03:21,957 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.contrastestimate" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s31/_fwhm_0/contrastestimate".
# 220714-19:03:31,547 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.contrastestimate" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s29/_fwhm_10/contrastestimate".
# 220714-19:03:35,364 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.contrastestimate" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s29/_fwhm_0/contrastestimate".
# 220714-19:03:41,64 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.contrastestimate" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s27/_fwhm_10/contrastestimate".
# 220714-19:03:45,920 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.contrastestimate" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s27/_fwhm_0/contrastestimate".
# 220714-19:03:46,40 nipype.workflow INFO:
# 	 [Job 43] Cached (level1.level1estimate).
# 220714-19:03:46,157 nipype.workflow INFO:
# 	 [Job 49] Cached (level1.level1estimate).
# 220714-19:03:46,294 nipype.workflow INFO:
# 	 [Job 56] Cached (level1.level1estimate).
# 220714-19:03:46,431 nipype.workflow INFO:
# 	 [Job 62] Cached (level1.level1estimate).
# 220714-19:03:46,566 nipype.workflow INFO:
# 	 [Job 69] Cached (level1.level1estimate).
# 220714-19:03:46,702 nipype.workflow INFO:
# 	 [Job 75] Cached (level1.level1estimate).
# 220714-19:03:46,721 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 31 jobs ready. Free memory (GB): 26.83/28.03, Free processors: 6/12.
#                      Currently running:
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
# 220714-19:03:51,895 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.contrastestimate" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s26/_fwhm_10/contrastestimate".
# 220714-19:03:57,126 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.contrastestimate" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s26/_fwhm_0/contrastestimate".
# 220714-19:04:06,315 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.contrastestimate" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s25/_fwhm_10/contrastestimate".
# 220714-19:04:13,33 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.contrastestimate" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s25/_fwhm_0/contrastestimate".
# 220714-19:04:18,834 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.contrastestimate" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s24/_fwhm_10/contrastestimate".
# 220714-19:04:24,737 nipype.workflow INFO:
# 	 [MultiProc] Running 12 tasks, and 25 jobs ready. Free memory (GB): 25.63/28.03, Free processors: 0/12.
#                      Currently running:
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
# 220714-19:04:24,743 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.contrastestimate" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s24/_fwhm_0/contrastestimate".
# 220714-19:05:15,754 nipype.workflow INFO:
# 	 [Node] Running "contrastestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 220714-19:05:39,730 nipype.workflow INFO:
# 	 [Node] Running "contrastestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 220714-19:06:25,726 nipype.workflow INFO:
# 	 [Node] Running "contrastestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 220714-19:07:00,252 nipype.workflow INFO:
# 	 [Node] Running "contrastestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 220714-19:07:11,408 nipype.workflow INFO:
# 	 [Node] Running "contrastestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 220714-19:07:16,875 nipype.workflow INFO:
# 	 [Node] Running "contrastestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 220714-19:07:26,234 nipype.workflow INFO:
# 	 [Node] Running "contrastestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 220714-19:07:33,459 nipype.workflow INFO:
# 	 [Node] Running "contrastestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 220714-19:07:37,175 nipype.workflow INFO:
# 	 [Node] Running "contrastestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 220714-19:07:41,57 nipype.workflow INFO:
# 	 [Node] Running "contrastestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 220714-19:07:44,858 nipype.workflow INFO:
# 	 [Node] Running "contrastestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 220714-19:07:57,435 nipype.workflow INFO:
# 	 [Node] Running "contrastestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 220714-19:34:38,830 nipype.workflow INFO:
# 	 [Node] Finished "level1.contrastestimate".
# 220714-19:34:40,466 nipype.workflow INFO:
# 	 [Job 24] Completed (level1.contrastestimate).
# 220714-19:34:40,476 nipype.workflow INFO:
# 	 [MultiProc] Running 11 tasks, and 26 jobs ready. Free memory (GB): 25.83/28.03, Free processors: 1/12.
#                      Currently running:
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
# 220714-19:34:40,909 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level1.datasink".
# 220714-19:34:40,924 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.datasink" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s29/_fwhm_0/datasink".
# 220714-19:34:40,969 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level1.datasink".
# 220714-19:34:41,71 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 220714-19:34:42,473 nipype.workflow INFO:
# 	 [MultiProc] Running 12 tasks, and 25 jobs ready. Free memory (GB): 25.63/28.03, Free processors: 0/12.
#                      Currently running:
#                        * level1.datasink
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
# 220714-19:34:45,60 nipype.workflow INFO:
# 	 [Node] Finished "level1.contrastestimate".
# 220714-19:34:45,579 nipype.workflow INFO:
# 	 [Node] Finished "level1.contrastestimate".
# 220714-19:34:45,754 nipype.workflow INFO:
# 	 [Node] Finished "level1.contrastestimate".
# 220714-19:34:46,472 nipype.workflow INFO:
# 	 [Job 44] Completed (level1.contrastestimate).
# 220714-19:34:46,480 nipype.workflow INFO:
# 	 [Job 50] Completed (level1.contrastestimate).
# 220714-19:34:46,490 nipype.workflow INFO:
# 	 [Job 70] Completed (level1.contrastestimate).
# 220714-19:34:46,497 nipype.workflow INFO:
# 	 [MultiProc] Running 9 tasks, and 28 jobs ready. Free memory (GB): 26.23/28.03, Free processors: 3/12.
#                      Currently running:
#                        * level1.datasink
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
# 220714-19:34:46,943 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level1.datasink".
# 220714-19:34:46,958 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.datasink" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s26/_fwhm_10/datasink".
# 220714-19:34:46,977 nipype.workflow INFO:
# 	 [Node] Finished "level1.datasink".
# 220714-19:34:46,973 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level1.datasink".
# 220714-19:34:47,126 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level1.datasink".
# 220714-19:34:47,101 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 220714-19:34:47,134 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.datasink" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s26/_fwhm_0/datasink".
# 220714-19:34:47,191 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level1.datasink".
# 220714-19:34:47,406 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 220714-19:34:47,461 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level1.datasink".
# 220714-19:34:47,468 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.datasink" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s24/_fwhm_10/datasink".
# 220714-19:34:47,482 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level1.datasink".
# 220714-19:34:47,668 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 220714-19:34:48,477 nipype.workflow INFO:
# 	 [Job 25] Completed (level1.datasink).
# 220714-19:34:48,498 nipype.workflow INFO:
# 	 [MultiProc] Running 11 tasks, and 25 jobs ready. Free memory (GB): 25.83/28.03, Free processors: 1/12.
#                      Currently running:
#                        * level1.datasink
#                        * level1.datasink
#                        * level1.datasink
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
# 220714-19:34:48,652 nipype.workflow INFO:
# 	 [Job 79] Cached (level1.smooth).
# 220714-19:34:49,240 nipype.workflow INFO:
# 	 [Node] Finished "level1.contrastestimate".
# 220714-19:34:50,474 nipype.workflow INFO:
# 	 [Job 76] Completed (level1.contrastestimate).
# 220714-19:34:50,478 nipype.workflow INFO:
# 	 [MultiProc] Running 10 tasks, and 26 jobs ready. Free memory (GB): 26.03/28.03, Free processors: 2/12.
#                      Currently running:
#                        * level1.datasink
#                        * level1.datasink
#                        * level1.datasink
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
# 220714-19:34:50,765 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level1.datasink".
# 220714-19:34:50,769 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.datasink" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s24/_fwhm_0/datasink".
# 220714-19:34:50,777 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level1.datasink".
# 220714-19:34:50,926 nipype.workflow INFO:
# 	 [Job 80] Cached (level1.modelspec).
# 220714-19:34:50,941 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 220714-19:34:52,458 nipype.workflow INFO:
# 	 [Node] Finished "level1.contrastestimate".
# 220714-19:34:52,475 nipype.workflow INFO:
# 	 [Job 57] Completed (level1.contrastestimate).
# 220714-19:34:52,478 nipype.workflow INFO:
# 	 [MultiProc] Running 10 tasks, and 26 jobs ready. Free memory (GB): 26.03/28.03, Free processors: 2/12.
#                      Currently running:
#                        * level1.datasink
#                        * level1.datasink
#                        * level1.datasink
#                        * level1.datasink
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
# 220714-19:34:52,963 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level1.datasink".
# 220714-19:34:52,973 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.datasink" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s25/_fwhm_10/datasink".
# 220714-19:34:52,978 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level1.datasink".
# 220714-19:34:53,184 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 220714-19:34:53,572 nipype.workflow INFO:
# 	 [Node] Finished "level1.contrastestimate".
# 220714-19:34:54,686 nipype.workflow INFO:
# 	 [Node] Finished "level1.contrastestimate".
# 220714-19:34:56,566 nipype.workflow INFO:
# 	 [Job 81] Cached (level1.level1design).
# 220714-19:34:56,573 nipype.workflow INFO:
# 	 [Job 31] Completed (level1.contrastestimate).
# 220714-19:34:56,575 nipype.workflow INFO:
# 	 [Job 63] Completed (level1.contrastestimate).
# 220714-19:34:56,578 nipype.workflow INFO:
# 	 [MultiProc] Running 9 tasks, and 27 jobs ready. Free memory (GB): 26.23/28.03, Free processors: 3/12.
#                      Currently running:
#                        * level1.datasink
#                        * level1.datasink
#                        * level1.datasink
#                        * level1.datasink
#                        * level1.datasink
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
# 220714-19:34:57,606 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level1.datasink".
# 220714-19:34:57,609 nipype.workflow INFO:
# 	 [Node] Finished "level1.contrastestimate".
# 220714-19:34:57,611 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.datasink" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s27/_fwhm_10/datasink".
# 220714-19:34:57,625 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level1.datasink".
# 220714-19:34:57,848 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 220714-19:34:58,231 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level1.datasink".
# 220714-19:34:58,235 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.datasink" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s25/_fwhm_0/datasink".
# 220714-19:34:58,248 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level1.datasink".
# 220714-19:34:58,279 nipype.workflow INFO:
# 	 [Job 82] Cached (level1.level1estimate).
# 220714-19:34:58,550 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 220714-19:34:58,572 nipype.workflow INFO:
# 	 [Job 37] Completed (level1.contrastestimate).
# 220714-19:34:58,576 nipype.workflow INFO:
# 	 [MultiProc] Running 10 tasks, and 26 jobs ready. Free memory (GB): 26.03/28.03, Free processors: 2/12.
#                      Currently running:
#                        * level1.datasink
#                        * level1.datasink
#                        * level1.datasink
#                        * level1.datasink
#                        * level1.datasink
#                        * level1.datasink
#                        * level1.datasink
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
# 220714-19:34:59,308 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level1.datasink".
# 220714-19:34:59,313 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.datasink" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s27/_fwhm_0/datasink".
# 220714-19:34:59,329 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level1.datasink".
# 220714-19:34:59,641 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 220714-19:35:01,289 nipype.workflow INFO:
# 	 [Node] Finished "level1.contrastestimate".
# 220714-19:35:01,442 nipype.workflow INFO:
# 	 [Node] Finished "level1.contrastestimate".
# 220714-19:35:02,209 nipype.workflow INFO:
# 	 [Node] Finished "level1.contrastestimate".
# 220714-19:35:02,530 nipype.workflow INFO:
# 	 [Job 5] Completed (level1.contrastestimate).
# 220714-19:35:02,533 nipype.workflow INFO:
# 	 [Job 11] Completed (level1.contrastestimate).
# 220714-19:35:02,535 nipype.workflow INFO:
# 	 [Job 18] Completed (level1.contrastestimate).
# 220714-19:35:02,534 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.contrastestimate" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s23/_fwhm_10/contrastestimate".
# 220714-19:35:02,539 nipype.workflow INFO:
# 	 [MultiProc] Running 9 tasks, and 27 jobs ready. Free memory (GB): 26.23/28.03, Free processors: 3/12.
#                      Currently running:
#                        * level1.contrastestimate
#                        * level1.datasink
#                        * level1.datasink
#                        * level1.datasink
#                        * level1.datasink
#                        * level1.datasink
#                        * level1.datasink
#                        * level1.datasink
#                        * level1.datasink
# 220714-19:35:03,326 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level1.datasink".
# 220714-19:35:03,330 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.datasink" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s31/_fwhm_10/datasink".
# 220714-19:35:03,344 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level1.datasink".
# 220714-19:35:03,641 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 220714-19:35:04,205 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level1.datasink".
# 220714-19:35:04,210 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.datasink" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s31/_fwhm_0/datasink".
# 220714-19:35:04,226 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level1.datasink".
# 220714-19:35:04,614 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 220714-19:35:05,79 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level1.datasink".
# 220714-19:35:05,84 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.datasink" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s29/_fwhm_10/datasink".
# 220714-19:35:05,87 nipype.workflow INFO:
# 	 [MultiProc] Running 12 tasks, and 24 jobs ready. Free memory (GB): 25.63/28.03, Free processors: 0/12.
#                      Currently running:
#                        * level1.datasink
#                        * level1.datasink
#                        * level1.datasink
#                        * level1.contrastestimate
#                        * level1.datasink
#                        * level1.datasink
#                        * level1.datasink
#                        * level1.datasink
#                        * level1.datasink
#                        * level1.datasink
#                        * level1.datasink
#                        * level1.datasink
# 220714-19:35:05,102 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level1.datasink".
# 220714-19:35:05,564 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 220714-19:36:45,628 nipype.workflow INFO:
# 	 [Node] Finished "level1.datasink".
# 220714-19:36:45,641 nipype.workflow INFO:
# 	 [Node] Finished "level1.datasink".
# 220714-19:36:46,375 nipype.workflow INFO:
# 	 [Node] Finished "level1.datasink".
# 220714-19:36:47,174 nipype.workflow INFO:
# 	 [Job 45] Completed (level1.datasink).
# 220714-19:36:47,175 nipype.workflow INFO:
# 	 [Job 51] Completed (level1.datasink).
# 220714-19:36:47,177 nipype.workflow INFO:
# 	 [Job 71] Completed (level1.datasink).
# 220714-19:36:47,182 nipype.workflow INFO:
# 	 [MultiProc] Running 9 tasks, and 24 jobs ready. Free memory (GB): 26.23/28.03, Free processors: 3/12.
#                      Currently running:
#                        * level1.datasink
#                        * level1.datasink
#                        * level1.datasink
#                        * level1.contrastestimate
#                        * level1.datasink
#                        * level1.datasink
#                        * level1.datasink
#                        * level1.datasink
#                        * level1.datasink
# 220714-19:36:47,190 nipype.workflow INFO:
# 	 [Node] Running "contrastestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 220714-19:36:47,330 nipype.workflow INFO:
# 	 [Job 85] Cached (level1.smooth).
# 220714-19:36:47,380 nipype.workflow INFO:
# 	 [Job 92] Cached (level1.smooth).
# 220714-19:36:47,415 nipype.workflow INFO:
# 	 [Job 98] Cached (level1.smooth).
# 220714-19:36:49,330 nipype.workflow INFO:
# 	 [Job 86] Cached (level1.modelspec).
# 220714-19:36:49,399 nipype.workflow INFO:
# 	 [Job 93] Cached (level1.modelspec).
# 220714-19:36:49,468 nipype.workflow INFO:
# 	 [Job 99] Cached (level1.modelspec).
# 220714-19:36:51,625 nipype.workflow INFO:
# 	 [Node] Finished "level1.datasink".
# 220714-19:36:51,724 nipype.workflow INFO:
# 	 [Job 87] Cached (level1.level1design).
# 220714-19:36:52,203 nipype.workflow INFO:
# 	 [Job 94] Cached (level1.level1design).
# 220714-19:36:52,670 nipype.workflow INFO:
# 	 [Job 100] Cached (level1.level1design).
# 220714-19:36:53,180 nipype.workflow INFO:
# 	 [Job 77] Completed (level1.datasink).
# 220714-19:36:53,196 nipype.workflow INFO:
# 	 [MultiProc] Running 8 tasks, and 24 jobs ready. Free memory (GB): 26.43/28.03, Free processors: 4/12.
#                      Currently running:
#                        * level1.datasink
#                        * level1.datasink
#                        * level1.datasink
#                        * level1.contrastestimate
#                        * level1.datasink
#                        * level1.datasink
#                        * level1.datasink
#                        * level1.datasink
# 220714-19:36:53,328 nipype.workflow INFO:
# 	 [Job 88] Cached (level1.level1estimate).
# 220714-19:36:53,363 nipype.workflow INFO:
# 	 [Job 95] Cached (level1.level1estimate).
# 220714-19:36:53,423 nipype.workflow INFO:
# 	 [Job 101] Cached (level1.level1estimate).
# 220714-19:36:53,478 nipype.workflow INFO:
# 	 [Job 105] Cached (level1.smooth).
# 220714-19:36:53,985 nipype.workflow INFO:
# 	 [Node] Finished "level1.datasink".
# 220714-19:36:55,177 nipype.workflow INFO:
# 	 [Job 58] Completed (level1.datasink).
# 220714-19:36:55,181 nipype.workflow INFO:
# 	 [MultiProc] Running 7 tasks, and 24 jobs ready. Free memory (GB): 26.63/28.03, Free processors: 5/12.
#                      Currently running:
#                        * level1.datasink
#                        * level1.datasink
#                        * level1.datasink
#                        * level1.contrastestimate
#                        * level1.datasink
#                        * level1.datasink
#                        * level1.datasink
# 220714-19:36:55,986 nipype.workflow INFO:
# 	 [Node] Finished "level1.datasink".
# 220714-19:36:56,403 nipype.workflow INFO:
# 	 [Node] Finished "level1.datasink".
# 220714-19:36:56,427 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.contrastestimate" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s23/_fwhm_0/contrastestimate".
# 220714-19:36:56,901 nipype.workflow INFO:
# 	 [Node] Finished "level1.datasink".
# 220714-19:36:57,552 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.contrastestimate" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s20/_fwhm_10/contrastestimate".
# 220714-19:36:58,747 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.contrastestimate" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s20/_fwhm_0/contrastestimate".
# 220714-19:36:58,773 nipype.workflow INFO:
# 	 [Job 106] Cached (level1.modelspec).
# 220714-19:36:58,800 nipype.workflow INFO:
# 	 [Job 111] Cached (level1.smooth).
# 220714-19:36:58,804 nipype.workflow INFO:
# 	 [Job 32] Completed (level1.datasink).
# 220714-19:36:58,804 nipype.workflow INFO:
# 	 [Node] Finished "level1.datasink".
# 220714-19:36:58,806 nipype.workflow INFO:
# 	 [Job 64] Completed (level1.datasink).
# 220714-19:36:58,809 nipype.workflow INFO:
# 	 [Job 38] Completed (level1.datasink).
# 220714-19:36:58,811 nipype.workflow INFO:
# 	 [Job 6] Completed (level1.datasink).
# 220714-19:36:58,814 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 21 jobs ready. Free memory (GB): 26.83/28.03, Free processors: 6/12.
#                      Currently running:
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.datasink
#                        * level1.datasink
#                        * level1.contrastestimate
# 220714-19:36:59,124 nipype.workflow INFO:
# 	 [Node] Finished "level1.datasink".
# 220714-19:36:59,245 nipype.workflow INFO:
# 	 [Node] Finished "level1.datasink".
# 220714-19:36:59,514 nipype.workflow INFO:
# 	 [Job 107] Cached (level1.level1design).
# 220714-19:36:59,557 nipype.workflow INFO:
# 	 [Job 112] Cached (level1.modelspec).
# 220714-19:36:59,589 nipype.workflow INFO:
# 	 [Job 118] Cached (level1.smooth).
# 220714-19:36:59,609 nipype.workflow INFO:
# 	 [Job 124] Cached (level1.smooth).
# 220714-19:36:59,642 nipype.workflow INFO:
# 	 [Job 131] Cached (level1.smooth).
# 220714-19:36:59,668 nipype.workflow INFO:
# 	 [Job 137] Cached (level1.smooth).
# 220714-19:37:00,805 nipype.workflow INFO:
# 	 [Job 12] Completed (level1.datasink).
# 220714-19:37:00,807 nipype.workflow INFO:
# 	 [Job 19] Completed (level1.datasink).
# 220714-19:37:00,811 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 21 jobs ready. Free memory (GB): 27.23/28.03, Free processors: 8/12.
#                      Currently running:
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
# 220714-19:37:01,17 nipype.workflow INFO:
# 	 [Job 108] Cached (level1.level1estimate).
# 220714-19:37:02,24 nipype.workflow INFO:
# 	 [Job 113] Cached (level1.level1design).
# 220714-19:37:02,58 nipype.workflow INFO:
# 	 [Job 119] Cached (level1.modelspec).
# 220714-19:37:02,99 nipype.workflow INFO:
# 	 [Job 125] Cached (level1.modelspec).
# 220714-19:37:02,138 nipype.workflow INFO:
# 	 [Job 132] Cached (level1.modelspec).
# 220714-19:37:02,174 nipype.workflow INFO:
# 	 [Job 138] Cached (level1.modelspec).
# 220714-19:37:02,203 nipype.workflow INFO:
# 	 [Job 144] Cached (level1.smooth).
# 220714-19:37:02,221 nipype.workflow INFO:
# 	 [Job 150] Cached (level1.smooth).
# 220714-19:37:03,682 nipype.workflow INFO:
# 	 [Job 114] Cached (level1.level1estimate).
# 220714-19:37:03,652 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.contrastestimate" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s19/_fwhm_10/contrastestimate".
# 220714-19:37:04,144 nipype.workflow INFO:
# 	 [Job 120] Cached (level1.level1design).
# 220714-19:37:04,652 nipype.workflow INFO:
# 	 [Job 126] Cached (level1.level1design).
# 220714-19:37:05,200 nipype.workflow INFO:
# 	 [Job 133] Cached (level1.level1design).
# 220714-19:37:05,748 nipype.workflow INFO:
# 	 [Job 139] Cached (level1.level1design).
# 220714-19:37:05,793 nipype.workflow INFO:
# 	 [Job 145] Cached (level1.modelspec).
# 220714-19:37:05,845 nipype.workflow INFO:
# 	 [Job 151] Cached (level1.modelspec).
# 220714-19:37:05,851 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 20 jobs ready. Free memory (GB): 27.03/28.03, Free processors: 7/12.
#                      Currently running:
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
# 220714-19:37:07,189 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.contrastestimate" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s19/_fwhm_0/contrastestimate".
# 220714-19:37:07,221 nipype.workflow INFO:
# 	 [Job 121] Cached (level1.level1estimate).
# 220714-19:37:07,270 nipype.workflow INFO:
# 	 [Job 127] Cached (level1.level1estimate).
# 220714-19:37:07,310 nipype.workflow INFO:
# 	 [Job 134] Cached (level1.level1estimate).
# 220714-19:37:07,342 nipype.workflow INFO:
# 	 [Job 140] Cached (level1.level1estimate).
# 220714-19:37:07,916 nipype.workflow INFO:
# 	 [Job 146] Cached (level1.level1design).
# 220714-19:37:08,455 nipype.workflow INFO:
# 	 [Job 152] Cached (level1.level1design).
# 220714-19:37:08,460 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 19 jobs ready. Free memory (GB): 26.83/28.03, Free processors: 6/12.
#                      Currently running:
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
# 220714-19:37:10,65 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.contrastestimate" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s18/_fwhm_10/contrastestimate".
# 220714-19:37:11,974 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.contrastestimate" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s18/_fwhm_0/contrastestimate".
# 220714-19:37:12,88 nipype.workflow INFO:
# 	 [Node] Running "contrastestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 220714-19:37:15,965 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.contrastestimate" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s16/_fwhm_10/contrastestimate".
# 220714-19:37:16,34 nipype.workflow INFO:
# 	 [Node] Running "contrastestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 220714-19:37:17,700 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.contrastestimate" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s16/_fwhm_0/contrastestimate".
# 220714-19:37:17,740 nipype.workflow INFO:
# 	 [Job 147] Cached (level1.level1estimate).
# 220714-19:37:17,770 nipype.workflow INFO:
# 	 [Job 153] Cached (level1.level1estimate).
# 220714-19:37:17,774 nipype.workflow INFO:
# 	 [MultiProc] Running 10 tasks, and 15 jobs ready. Free memory (GB): 26.03/28.03, Free processors: 2/12.
#                      Currently running:
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
# 220714-19:37:17,942 nipype.workflow INFO:
# 	 [Node] Running "contrastestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 220714-19:37:19,661 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.contrastestimate" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s15/_fwhm_10/contrastestimate".
# 220714-19:37:21,680 nipype.workflow INFO:
# 	 [MultiProc] Running 12 tasks, and 13 jobs ready. Free memory (GB): 25.63/28.03, Free processors: 0/12.
#                      Currently running:
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
# 220714-19:37:21,683 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.contrastestimate" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s15/_fwhm_0/contrastestimate".
# 220714-19:37:25,481 nipype.workflow INFO:
# 	 [Node] Running "contrastestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 220714-19:37:33,557 nipype.workflow INFO:
# 	 [Node] Running "contrastestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 220714-19:37:37,110 nipype.workflow INFO:
# 	 [Node] Running "contrastestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 220714-19:37:38,557 nipype.workflow INFO:
# 	 [Node] Running "contrastestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 220714-19:37:39,839 nipype.workflow INFO:
# 	 [Node] Running "contrastestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 220714-19:37:40,907 nipype.workflow INFO:
# 	 [Node] Running "contrastestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 220714-19:37:41,637 nipype.workflow INFO:
# 	 [Node] Running "contrastestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 220714-19:37:42,60 nipype.workflow INFO:
# 	 [Node] Running "contrastestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 220714-19:43:38,890 nipype.workflow INFO:
# 	 [Node] Finished "level1.contrastestimate".
# 220714-19:43:40,35 nipype.workflow INFO:
# 	 [Job 96] Completed (level1.contrastestimate).
# 220714-19:43:40,49 nipype.workflow INFO:
# 	 [MultiProc] Running 11 tasks, and 14 jobs ready. Free memory (GB): 25.83/28.03, Free processors: 1/12.
#                      Currently running:
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
# 220714-19:43:41,12 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level1.datasink".
# 220714-19:43:41,17 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.datasink" in "/media/tw260/X6/Effort/analysis/workingdir-Effort-Model1/level1/_subject_id_s20/_fwhm_10/datasink".
# 220714-19:43:41,28 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level1.datasink".
# 220714-19:43:41,187 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 220714-19:43:42,35 nipype.workflow INFO:
# 	 [MultiProc] Running 12 tasks, and 13 jobs ready. Free memory (GB): 25.63/28.03, Free processors: 0/12.
#                      Currently running:
#                        * level1.datasink
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
# 220714-19:43:45,263 nipype.workflow INFO:
# 	 [Node] Finished "level1.contrastestimate".
# 220714-19:43:46,37 nipype.workflow INFO:
# 	 [Job 83] Completed (level1.contrastestimate).
# 220714-19:43:46,42 nipype.workflow INFO:
# 	 [MultiProc] Running 11 tasks, and 14 jobs ready. Free memory (GB): 25.83/28.03, Free processors: 1/12.
#                      Currently running:
#                        * level1.datasink
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
#                        * level1.contrastestimate
# ...
# 220714-20:39:33,864 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.level2conestimate".
# 220714-20:39:33,870 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.level2conestimate" in "/media/tw260/X6/Effort/analysis/l2output-Effort-Model1/level2/_con_6_fwhm_0/level2conestimate".
# 220714-20:39:33,893 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.level2conestimate".
# 220714-20:39:34,201 nipype.workflow INFO:
# 	 [Node] Running "level2conestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 220714-20:39:35,660 nipype.workflow INFO:
# 	 [MultiProc] Running 12 tasks, and 0 jobs ready. Free memory (GB): 25.63/28.03, Free processors: 0/12.
#                      Currently running:
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2estimate
#                        * level2.level2estimate
#                        * level2.level2estimate
#                        * level2.level2estimate
#                        * level2.level2estimate
# 220714-20:39:38,530 nipype.workflow INFO:
# 	 [Node] Finished "level2.level2estimate".
# 220714-20:39:39,662 nipype.workflow INFO:
# 	 [Job 174] Completed (level2.level2estimate).
# 220714-20:39:39,666 nipype.workflow INFO:
# 	 [MultiProc] Running 11 tasks, and 1 jobs ready. Free memory (GB): 25.83/28.03, Free processors: 1/12.
#                      Currently running:
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2estimate
#                        * level2.level2estimate
#                        * level2.level2estimate
#                        * level2.level2estimate
# 220714-20:39:40,85 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.level2conestimate".
# 220714-20:39:40,95 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.level2conestimate" in "/media/tw260/X6/Effort/analysis/l2output-Effort-Model1/level2/_con_5_fwhm_0/level2conestimate".
# 220714-20:39:40,115 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.level2conestimate".
# 220714-20:39:40,386 nipype.workflow INFO:
# 	 [Node] Running "level2conestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 220714-20:39:41,666 nipype.workflow INFO:
# 	 [MultiProc] Running 12 tasks, and 0 jobs ready. Free memory (GB): 25.63/28.03, Free processors: 0/12.
#                      Currently running:
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2estimate
#                        * level2.level2estimate
#                        * level2.level2estimate
#                        * level2.level2estimate
# 220714-20:39:44,62 nipype.workflow INFO:
# 	 [Node] Finished "level2.level2estimate".
# 220714-20:39:45,668 nipype.workflow INFO:
# 	 [Job 186] Completed (level2.level2estimate).
# 220714-20:39:45,672 nipype.workflow INFO:
# 	 [MultiProc] Running 11 tasks, and 1 jobs ready. Free memory (GB): 25.83/28.03, Free processors: 1/12.
#                      Currently running:
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2estimate
#                        * level2.level2estimate
#                        * level2.level2estimate
# 220714-20:39:45,914 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.level2conestimate".
# 220714-20:39:45,928 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.level2conestimate" in "/media/tw260/X6/Effort/analysis/l2output-Effort-Model1/level2/_con_2_fwhm_0/level2conestimate".
# 220714-20:39:45,959 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.level2conestimate".
# 220714-20:39:46,668 nipype.workflow INFO:
# 	 [Node] Running "level2conestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 220714-20:39:47,671 nipype.workflow INFO:
# 	 [MultiProc] Running 12 tasks, and 0 jobs ready. Free memory (GB): 25.63/28.03, Free processors: 0/12.
#                      Currently running:
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2estimate
#                        * level2.level2estimate
#                        * level2.level2estimate
# 220714-20:39:55,566 nipype.workflow INFO:
# 	 [Node] Finished "level2.level2estimate".
# 220714-20:39:55,678 nipype.workflow INFO:
# 	 [Job 182] Completed (level2.level2estimate).
# 220714-20:39:55,682 nipype.workflow INFO:
# 	 [MultiProc] Running 11 tasks, and 1 jobs ready. Free memory (GB): 25.83/28.03, Free processors: 1/12.
#                      Currently running:
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2estimate
#                        * level2.level2estimate
# 220714-20:39:55,785 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.level2conestimate".
# 220714-20:39:55,791 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.level2conestimate" in "/media/tw260/X6/Effort/analysis/l2output-Effort-Model1/level2/_con_3_fwhm_0/level2conestimate".
# 220714-20:39:55,796 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.level2conestimate".
# 220714-20:39:55,994 nipype.workflow INFO:
# 	 [Node] Running "level2conestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 220714-20:39:57,681 nipype.workflow INFO:
# 	 [MultiProc] Running 12 tasks, and 0 jobs ready. Free memory (GB): 25.63/28.03, Free processors: 0/12.
#                      Currently running:
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2estimate
#                        * level2.level2estimate
# 220714-20:39:57,884 nipype.workflow INFO:
# 	 [Node] Finished "level2.level2estimate".
# 220714-20:39:59,382 nipype.workflow INFO:
# 	 [Node] Finished "level2.level2estimate".
# 220714-20:39:59,682 nipype.workflow INFO:
# 	 [Job 178] Completed (level2.level2estimate).
# 220714-20:39:59,685 nipype.workflow INFO:
# 	 [Job 190] Completed (level2.level2estimate).
# 220714-20:39:59,691 nipype.workflow INFO:
# 	 [MultiProc] Running 10 tasks, and 2 jobs ready. Free memory (GB): 26.03/28.03, Free processors: 2/12.
#                      Currently running:
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
# 220714-20:39:59,897 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.level2conestimate".
# 220714-20:39:59,907 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.level2conestimate" in "/media/tw260/X6/Effort/analysis/l2output-Effort-Model1/level2/_con_4_fwhm_0/level2conestimate".
# 220714-20:39:59,936 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.level2conestimate".
# 220714-20:39:59,974 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.level2conestimate".
# 220714-20:39:59,980 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.level2conestimate" in "/media/tw260/X6/Effort/analysis/l2output-Effort-Model1/level2/_con_1_fwhm_0/level2conestimate".
# 220714-20:40:00,21 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.level2conestimate".
# 220714-20:40:00,537 nipype.workflow INFO:
# 	 [Node] Running "level2conestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 220714-20:40:00,548 nipype.workflow INFO:
# 	 [Node] Running "level2conestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 220714-20:40:01,685 nipype.workflow INFO:
# 	 [MultiProc] Running 12 tasks, and 0 jobs ready. Free memory (GB): 25.63/28.03, Free processors: 0/12.
#                      Currently running:
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
# 220714-20:40:13,237 nipype.workflow INFO:
# 	 [Node] Finished "level2.level2conestimate".
# 220714-20:40:13,697 nipype.workflow INFO:
# 	 [Job 155] Completed (level2.level2conestimate).
# 220714-20:40:13,704 nipype.workflow INFO:
# 	 [MultiProc] Running 11 tasks, and 0 jobs ready. Free memory (GB): 25.83/28.03, Free processors: 1/12.
#                      Currently running:
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
# 220714-20:40:13,735 nipype.workflow INFO:
# 	 [Node] Finished "level2.level2conestimate".
# 220714-20:40:14,172 nipype.workflow INFO:
# 	 [Node] Finished "level2.level2conestimate".
# 220714-20:40:15,111 nipype.workflow INFO:
# 	 [Node] Finished "level2.level2conestimate".
# 220714-20:40:15,197 nipype.workflow INFO:
# 	 [Node] Finished "level2.level2conestimate".
# 220714-20:40:15,320 nipype.workflow INFO:
# 	 [Node] Finished "level2.level2conestimate".
# 220714-20:40:15,698 nipype.workflow INFO:
# 	 [Job 151] Completed (level2.level2conestimate).
# 220714-20:40:15,701 nipype.workflow INFO:
# 	 [Job 159] Completed (level2.level2conestimate).
# 220714-20:40:15,703 nipype.workflow INFO:
# 	 [Job 163] Completed (level2.level2conestimate).
# 220714-20:40:15,707 nipype.workflow INFO:
# 	 [Job 167] Completed (level2.level2conestimate).
# 220714-20:40:15,708 nipype.workflow INFO:
# 	 [Job 147] Completed (level2.level2conestimate).
# 220714-20:40:15,713 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 0 jobs ready. Free memory (GB): 26.83/28.03, Free processors: 6/12.
#                      Currently running:
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
# 220714-20:40:57,238 nipype.workflow INFO:
# 	 [Node] Finished "level2.level2conestimate".
# 220714-20:40:57,737 nipype.workflow INFO:
# 	 [Job 175] Completed (level2.level2conestimate).
# 220714-20:40:57,742 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 0 jobs ready. Free memory (GB): 27.03/28.03, Free processors: 7/12.
#                      Currently running:
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
# 220714-20:41:05,651 nipype.workflow INFO:
# 	 [Node] Finished "level2.level2conestimate".
# 220714-20:41:05,745 nipype.workflow INFO:
# 	 [Job 187] Completed (level2.level2conestimate).
# 220714-20:41:05,750 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 0 jobs ready. Free memory (GB): 27.23/28.03, Free processors: 8/12.
#                      Currently running:
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
# 220714-20:41:05,819 nipype.workflow INFO:
# 	 [Node] Finished "level2.level2conestimate".
# 220714-20:41:07,746 nipype.workflow INFO:
# 	 [Job 171] Completed (level2.level2conestimate).
# 220714-20:41:07,749 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 0 jobs ready. Free memory (GB): 27.43/28.03, Free processors: 9/12.
#                      Currently running:
#                        * level2.level2conestimate
#                        * level2.level2conestimate
#                        * level2.level2conestimate
# 220714-20:41:08,637 nipype.workflow INFO:
# 	 [Node] Finished "level2.level2conestimate".
# 220714-20:41:09,745 nipype.workflow INFO:
# 	 [Job 183] Completed (level2.level2conestimate).
# 220714-20:41:09,748 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 27.63/28.03, Free processors: 10/12.
#                      Currently running:
#                        * level2.level2conestimate
#                        * level2.level2conestimate
# 220714-20:41:13,889 nipype.workflow INFO:
# 	 [Node] Finished "level2.level2conestimate".
# 220714-20:41:15,750 nipype.workflow INFO:
# 	 [Job 179] Completed (level2.level2conestimate).
# 220714-20:41:15,753 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 27.83/28.03, Free processors: 11/12.
#                      Currently running:
#                        * level2.level2conestimate
# 220714-20:41:18,146 nipype.workflow INFO:
# 	 [Node] Finished "level2.level2conestimate".
# 220714-20:41:19,753 nipype.workflow INFO:
# 	 [Job 191] Completed (level2.level2conestimate).
# 220714-20:41:19,756 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 28.03/28.03, Free processors: 12/12.

# %%
from nipype.utils.filemanip import loadpkl
res = loadpkl('/media/tw260/X6/Effort/fMRI commands/crash-20220429-160232-tw260-datasource.b0-b9bd5054-4da1-4cd3-bebc-3e3f0bb888d3.pklz')
print(res)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-21-5fc84d5c1332> in <module>
#       1 from nipype.utils.filemanip import loadpkl
# ----> 2 res = loadpkl('/media/tw260/X6/Effort/fMRI commands/crash-20220429-160232-tw260-datasource.b0-b9bd5054-4da1-4cd3-bebc-3e3f0bb888d3.pklz')
#       3 print(res)
#
# ~/.local/lib/python3.8/site-packages/nipype/utils/filemanip.py in loadpkl(infile)
#     623             "seconds.".format(infile, timeout)
#     624         )
# --> 625         raise IOError(error_message)
#     626
#     627     with pklopen(str(infile), "rb") as pkl_file:
#
# OSError: Result file /media/tw260/X6/Effort/fMRI commands/crash-20220429-160232-tw260-datasource.b0-b9bd5054-4da1-4cd3-bebc-3e3f0bb888d3.pklz expected, but does not exist after (5.0) seconds.
